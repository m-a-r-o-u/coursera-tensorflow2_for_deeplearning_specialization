# %% [markdown]
# # Capstone Project
# ## Image classifier for the SVHN dataset
# ### Instructions
#
# In this notebook, you will create a neural network that classifies real-world images digits. You will use concepts from throughout this course in building, training, testing, validating and saving your Tensorflow classifier model.
#
# This project is peer-assessed. Within this notebook you will find instructions in each section for how to complete the project. Pay close attention to the instructions as the peer review will be carried out according to a grading rubric that checks key parts of the project instructions. Feel free to add extra cells into the notebook as required.
#
# ### How to submit
#
# When you have completed the Capstone project notebook, you will submit a pdf of the notebook for peer review. First ensure that the notebook has been fully executed from beginning to end, and all of the cell outputs are visible. This is important, as the grading rubric depends on the reviewer being able to view the outputs of your notebook. Save the notebook as a pdf (you could download the notebook with File -> Download .ipynb, open the notebook locally, and then File -> Download as -> PDF via LaTeX), and then submit this pdf for review.
#
# ### Let's get started!
#
# We'll start by running some imports, and loading the dataset. For this project you are free to make further imports throughout the notebook as you wish.

# %%
import tensorflow as tf
import tarfile
import matplotlib.pyplot as plt
import numpy as np
import os

from scipy.io import loadmat
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPool2D, BatchNormalization, Dropout

# %% [markdown]
# For the capstone project, you will use the [SVHN dataset](http://ufldl.stanford.edu/housenumbers/). This is an image dataset of over 600,000 digit images in all, and is a harder dataset than MNIST as the numbers appear in the context of natural scene images. SVHN is obtained from house numbers in Google Street View images.
#
# * Y. Netzer, T. Wang, A. Coates, A. Bissacco, B. Wu and A. Y. Ng. "Reading Digits in Natural Images with Unsupervised Feature Learning". NIPS Workshop on Deep Learning and Unsupervised Feature Learning, 2011.
#
# The train and test datasets required for this project can be downloaded from [here](http://ufldl.stanford.edu/housenumbers/train.tar.gz) and [here](http://ufldl.stanford.edu/housenumbers/test.tar.gz). Once unzipped, you will have two files: `train_32x32.mat` and `test_32x32.mat`. You should store these files in Drive for use in this Colab notebook.
#
# Your goal is to develop an end-to-end workflow for building, training, validating, evaluating and saving a neural network that classifies a real-world image into one of ten classes.

# %%
# Run this cell to connect to your Drive folder

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
data_path = './gdrive/MyDrive/Colab Notebooks/data/SVHN/'
fnames = [os.path.join(data_path, 'train.tar.gz'),
          os.path.join(data_path, 'test.tar.gz')]

for fname in fnames:
  with tarfile.open(fname, 'r:gz') as tf:
    tf.extractall()

# %%
# Load the dataset from your Drive folder

train = loadmat(os.path.join(data_path, 'train_32x32.mat'))
test = loadmat(os.path.join(data_path, 'test_32x32.mat'))

# %% [markdown]
# Both `train` and `test` are dictionaries with keys `X` and `y` for the input images and labels respectively.

# %% [markdown]
# ## 1. Inspect and preprocess the dataset
# * Extract the training and testing images and labels separately from the train and test dictionaries loaded for you.
# * Select a random sample of images and corresponding labels from the dataset (at least 10), and display them in a figure.
# * Convert the training and test images to grayscale by taking the average across all colour channels for each pixel. _Hint: retain the channel dimension, which will now have size 1._
# * Select a random sample of the grayscale images and corresponding labels from the dataset (at least 10), and display them in a figure.

# %%
train_X = np.moveaxis(train['X'], -1, 0)
train_y = train['y']
test_X = np.moveaxis(test['X'], -1, 0)
test_y = test['y']

# %%
def plot_sample_images(x, y, model=None, cmap=None):
  fig, axs = plt.subplots(1,10, figsize=(20, 30))
  img_idx = list(range(x.shape[0]))
  np.random.shuffle(img_idx)
  for i, idx in enumerate(img_idx[:10]):
    axs[i].axis('off')
    axs[i].imshow(np.squeeze(x[idx]), cmap=cmap)
    if not model:
      axs[i].set_title(str(np.squeeze(y[idx])))
    else:
      xp = x[idx]
      xp = xp[np.newaxis, ...]
      pred = model.predict(xp)
      out = np.argmax(pred) + 1
      axs[i].set_title(str(np.squeeze(y[idx])) +'=='+ str(out))

# %%
plot_sample_images(train_X, train_y)

# %%
gray_train_X = train_X.mean(axis=-1, keepdims=True)
gray_test_X = test_X.mean(axis=-1, keepdims=True)
index_train_y = train_y - 1
index_test_y = test_y - 1

# %%
plot_sample_images(gray_train_X, train_y, cmap='gray')

# %%
print(train_X.shape, gray_train_X.shape, train_y.shape)
# Out:
# (73257, 32, 32, 3) (73257, 32, 32, 1) (73257, 1)

# %%
print(test_X.shape, gray_test_X.shape, test_y.shape)
# Out:
# (26032, 32, 32, 3) (26032, 32, 32, 1) (26032, 1)

# %% [markdown]
# ## 2. MLP neural network classifier
# * Build an MLP classifier model using the Sequential API. Your model should use only Flatten and Dense layers, with the final layer having a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different MLP architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 4 or 5 layers._
# * Print out the model summary (using the summary() method)
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * As a guide, you should aim to achieve a final categorical cross entropy training loss of less than 1.0 (the validation loss might be higher).
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
def get_new_model(input_shape):
  model = Sequential([
      Flatten(input_shape=input_shape),
      Dense(256, activation='relu'),
      Dense(128, activation='relu'),
      Dense(64, activation='relu'),
      Dense(32, activation='relu'),
      Dense(10, activation='softmax'),
  ])
  return model

model = get_new_model(gray_train_X.shape[1:])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               262400
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_7 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_9 (Dense)              (None, 10)                330
# =================================================================
# Total params: 305,962
# Trainable params: 305,962
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.00005)
model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model_checkpoint = ModelCheckpoint(frequency='epoch',
                                   save_weights_only=True,
                                   save_best_only=True,
                                   monitor='val_accuracy',
                                   filepath='checkpoints/checkpoint')
early_stopping = EarlyStopping(patience=5, monitor='val_accuracy')

# %%
history = model.fit(
    gray_train_X,
    index_train_y,
    batch_size=64,
    validation_split=0.1,
    epochs=60,
    callbacks=[model_checkpoint, early_stopping]
    )
# Out:
# Epoch 1/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 10.7311 - accuracy: 0.1359 - val_loss: 2.2840 - val_accuracy: 0.1582
# Epoch 2/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 2.2330 - accuracy: 0.1933 - val_loss: 2.1377 - val_accuracy: 0.2606
# Epoch 3/60
# 1031/1031 [==============================] - 2s 2ms/step - loss: 2.0874 - accuracy: 0.2824 - val_loss: 2.1140 - val_accuracy: 0.2655
# Epoch 4/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 2.0149 - accuracy: 0.3025 - val_loss: 1.9835 - val_accuracy: 0.3168
# Epoch 5/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.9226 - accuracy: 0.3408 - val_loss: 1.9105 - val_accuracy: 0.3397
# Epoch 6/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.8645 - accuracy: 0.3599 - val_loss: 1.8589 - val_accuracy: 0.3554
# Epoch 7/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.8247 - accuracy: 0.3695 - val_loss: 1.8134 - val_accuracy: 0.3683
# Epoch 8/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.7829 - accuracy: 0.3809 - val_loss: 1.7957 - val_accuracy: 0.3638
# Epoch 9/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.7391 - accuracy: 0.3988 - val_loss: 1.7435 - val_accuracy: 0.4091
# Epoch 10/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.7149 - accuracy: 0.4197 - val_loss: 1.9058 - val_accuracy: 0.3613
# Epoch 11/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 1.6982 - accuracy: 0.4209 - val_loss: 1.6871 - val_accuracy: 0.3968
# Epoch 12/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 1.6145 - accuracy: 0.4344 - val_loss: 1.6797 - val_accuracy: 0.3969
# Epoch 13/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 1.5620 - accuracy: 0.4530 - val_loss: 1.5918 - val_accuracy: 0.4346
# Epoch 14/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 1.5322 - accuracy: 0.4632 - val_loss: 1.5522 - val_accuracy: 0.4521
# Epoch 15/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 1.5071 - accuracy: 0.4786 - val_loss: 1.5340 - val_accuracy: 0.4922
# Epoch 16/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.4772 - accuracy: 0.5047 - val_loss: 1.5390 - val_accuracy: 0.4839
# Epoch 17/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.4436 - accuracy: 0.5175 - val_loss: 1.4918 - val_accuracy: 0.4990
# Epoch 18/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.4142 - accuracy: 0.5264 - val_loss: 1.4439 - val_accuracy: 0.5150
# Epoch 19/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.3998 - accuracy: 0.5282 - val_loss: 1.4449 - val_accuracy: 0.5206
# Epoch 20/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.3703 - accuracy: 0.5380 - val_loss: 1.3945 - val_accuracy: 0.5339
# Epoch 21/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.3459 - accuracy: 0.5483 - val_loss: 1.4347 - val_accuracy: 0.5139
# Epoch 22/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 1.3168 - accuracy: 0.5582 - val_loss: 1.3257 - val_accuracy: 0.5580
# Epoch 23/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.2878 - accuracy: 0.5695 - val_loss: 1.2837 - val_accuracy: 0.5782
# Epoch 24/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.2661 - accuracy: 0.5802 - val_loss: 1.3053 - val_accuracy: 0.5602
# Epoch 25/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 1.2231 - accuracy: 0.5953 - val_loss: 1.2815 - val_accuracy: 0.5842
# Epoch 26/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.1995 - accuracy: 0.6001 - val_loss: 1.2400 - val_accuracy: 0.5879
# Epoch 27/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.1823 - accuracy: 0.6093 - val_loss: 1.2169 - val_accuracy: 0.6040
# Epoch 28/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.1542 - accuracy: 0.6163 - val_loss: 1.2174 - val_accuracy: 0.5902
# Epoch 29/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.1346 - accuracy: 0.6263 - val_loss: 1.1451 - val_accuracy: 0.6263
# Epoch 30/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.1110 - accuracy: 0.6399 - val_loss: 1.1315 - val_accuracy: 0.6417
# Epoch 31/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.0888 - accuracy: 0.6500 - val_loss: 1.1317 - val_accuracy: 0.6402
# Epoch 32/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.0596 - accuracy: 0.6630 - val_loss: 1.0970 - val_accuracy: 0.6462
# Epoch 33/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 1.0421 - accuracy: 0.6683 - val_loss: 1.1003 - val_accuracy: 0.6517
# Epoch 34/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.0352 - accuracy: 0.6703 - val_loss: 1.0825 - val_accuracy: 0.6626
# Epoch 35/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.0046 - accuracy: 0.6806 - val_loss: 1.0715 - val_accuracy: 0.6675
# Epoch 36/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 1.0016 - accuracy: 0.6820 - val_loss: 1.0492 - val_accuracy: 0.6777
# Epoch 37/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 0.9828 - accuracy: 0.6874 - val_loss: 1.0114 - val_accuracy: 0.6854
# Epoch 38/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.9581 - accuracy: 0.6965 - val_loss: 1.0333 - val_accuracy: 0.6889
# Epoch 39/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.9455 - accuracy: 0.7017 - val_loss: 1.0372 - val_accuracy: 0.6734
# Epoch 40/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.9372 - accuracy: 0.7050 - val_loss: 1.0430 - val_accuracy: 0.6706
# Epoch 41/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.9241 - accuracy: 0.7116 - val_loss: 0.9860 - val_accuracy: 0.6994
# Epoch 42/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.9089 - accuracy: 0.7161 - val_loss: 0.9834 - val_accuracy: 0.7017
# Epoch 43/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.8940 - accuracy: 0.7208 - val_loss: 0.9630 - val_accuracy: 0.7110
# Epoch 44/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.8771 - accuracy: 0.7265 - val_loss: 0.9691 - val_accuracy: 0.7054
# Epoch 45/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.8682 - accuracy: 0.7326 - val_loss: 1.0029 - val_accuracy: 0.7022
# Epoch 46/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 0.8517 - accuracy: 0.7333 - val_loss: 0.9479 - val_accuracy: 0.7150
# Epoch 47/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.8520 - accuracy: 0.7325 - val_loss: 0.9555 - val_accuracy: 0.7164
# Epoch 48/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.8271 - accuracy: 0.7455 - val_loss: 0.9264 - val_accuracy: 0.7235
# Epoch 49/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.8277 - accuracy: 0.7439 - val_loss: 0.9132 - val_accuracy: 0.7277
# Epoch 50/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.8155 - accuracy: 0.7486 - val_loss: 0.9114 - val_accuracy: 0.7314
# Epoch 51/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.8030 - accuracy: 0.7518 - val_loss: 0.9130 - val_accuracy: 0.7293
# Epoch 52/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 0.7946 - accuracy: 0.7550 - val_loss: 0.8940 - val_accuracy: 0.7364
# Epoch 53/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.7841 - accuracy: 0.7600 - val_loss: 0.9325 - val_accuracy: 0.7191
# Epoch 54/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.7766 - accuracy: 0.7600 - val_loss: 0.9326 - val_accuracy: 0.7250
# Epoch 55/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.7684 - accuracy: 0.7638 - val_loss: 0.9013 - val_accuracy: 0.7310
# Epoch 56/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.7612 - accuracy: 0.7667 - val_loss: 0.9077 - val_accuracy: 0.7286
# Epoch 57/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.7584 - accuracy: 0.7688 - val_loss: 0.8955 - val_accuracy: 0.7404
# Epoch 58/60
# 1031/1031 [==============================] - 3s 3ms/step - loss: 0.7437 - accuracy: 0.7731 - val_loss: 0.8959 - val_accuracy: 0.7334
# Epoch 59/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.7335 - accuracy: 0.7749 - val_loss: 0.8873 - val_accuracy: 0.7345
# Epoch 60/60
# 1031/1031 [==============================] - 3s 2ms/step - loss: 0.7331 - accuracy: 0.7756 - val_loss: 0.9146 - val_accuracy: 0.7304

# %%
def plot_metrics(h):
  fig, axs = plt.subplots(1,2, figsize=(12, 6))
  axs[0].plot(h['loss'], label='loss')
  axs[0].plot(h['val_loss'], label='val_loss')
  axs[0].legend()

  axs[1].plot(h['accuracy'], label='accuracy')
  axs[1].plot(h['val_accuracy'], label='val_accuracy')
  axs[1].legend()
  
plot_metrics(history.history)

# %% [markdown]
# ## 3. CNN neural network classifier
# * Build a CNN classifier model using the Sequential API. Your model should use the Conv2D, MaxPool2D, BatchNormalization, Flatten, Dense and Dropout layers. The final layer should again have a 10-way softmax output.
# * You should design and build the model yourself. Feel free to experiment with different CNN architectures. _Hint: to achieve a reasonable accuracy you won't need to use more than 2 or 3 convolutional layers and 2 fully connected layers.)_
# * The CNN model should use fewer trainable parameters than your MLP model.
# * Compile and train the model (we recommend a maximum of 30 epochs), making use of both training and validation sets during the training run.
# * Your model should track at least one appropriate metric, and use at least two callbacks during training, one of which should be a ModelCheckpoint callback.
# * You should aim to beat the MLP model performance with fewer parameters!
# * Plot the learning curves for loss vs epoch and accuracy vs epoch for both training and validation sets.
# * Compute and display the loss and accuracy of the trained model on the test set.

# %%
def get_new_cnn_model(input_shape, droprate=0.3):
  model = Sequential([
      Conv2D(64, (4,4), padding='SAME', input_shape=input_shape, activation='relu'),
      Dropout(droprate),
      MaxPool2D((2,2)),    
      BatchNormalization(),
      Conv2D(64, (4,4), padding='SAME', activation='relu'),
      Dropout(droprate),
      MaxPool2D((2,2)),
      BatchNormalization(),    
      Conv2D(64, (4,4), padding='SAME', activation='relu'),
      Dropout(droprate),
      MaxPool2D((2,2)),
      BatchNormalization(),
      Flatten(),
      Dense(64, activation='relu'),
      Dropout(droprate),
      Dense(32, activation='relu'),
      Dropout(droprate),
      Dense(10, activation='softmax')
  ])
  return model

# %%
cnn_model = get_new_cnn_model(gray_train_X.shape[1:])
cnn_model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_20 (Conv2D)           (None, 32, 32, 64)        1088
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 32, 32, 64)        0
# _________________________________________________________________
# max_pooling2d_20 (MaxPooling (None, 16, 16, 64)        0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 16, 16, 64)        256
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 16, 16, 64)        65600
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 16, 16, 64)        0
# _________________________________________________________________
# max_pooling2d_21 (MaxPooling (None, 8, 8, 64)          0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 8, 8, 64)          65600
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 8, 8, 64)          0
# _________________________________________________________________
# max_pooling2d_22 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 4, 4, 64)          256
# _________________________________________________________________
# flatten_10 (Flatten)         (None, 1024)              0
# _________________________________________________________________
# dense_34 (Dense)             (None, 64)                65600
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 64)                0
# _________________________________________________________________
# dense_35 (Dense)             (None, 32)                2080
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_36 (Dense)             (None, 10)                330
# =================================================================
# Total params: 201,066
# Trainable params: 200,682
# Non-trainable params: 384
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(learning_rate=0.0001)
cnn_model.compile(optimizer=opt, loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model_checkpoint_cnn = ModelCheckpoint(
    frequency='epoch',
    save_weights_only=True,
    save_best_only=True,
    monitor='val_accuracy',
    filepath='checkpoints_cnn/checkpoint_{epoch:04d}'
)

# %%
history_cnn = cnn_model.fit(
    gray_train_X, 
    index_train_y,
    batch_size=64,
    validation_split=0.3,
    epochs=60,
    callbacks=[model_checkpoint_cnn, early_stopping]
)
# Out:
# Epoch 1/60
# 802/802 [==============================] - 8s 9ms/step - loss: 2.3553 - accuracy: 0.1321 - val_loss: 2.0708 - val_accuracy: 0.3055
# Epoch 2/60
# 802/802 [==============================] - 7s 9ms/step - loss: 1.7979 - accuracy: 0.3706 - val_loss: 1.1764 - val_accuracy: 0.6632
# Epoch 3/60
# 802/802 [==============================] - 7s 9ms/step - loss: 1.2173 - accuracy: 0.5954 - val_loss: 0.8573 - val_accuracy: 0.7584
# Epoch 4/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.9393 - accuracy: 0.7045 - val_loss: 0.6779 - val_accuracy: 0.8044
# Epoch 5/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7905 - accuracy: 0.7558 - val_loss: 0.6048 - val_accuracy: 0.8340
# Epoch 6/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.7076 - accuracy: 0.7833 - val_loss: 0.5041 - val_accuracy: 0.8582
# Epoch 7/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6502 - accuracy: 0.8081 - val_loss: 0.5031 - val_accuracy: 0.8574
# Epoch 8/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.6000 - accuracy: 0.8209 - val_loss: 0.4895 - val_accuracy: 0.8572
# Epoch 9/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5779 - accuracy: 0.8308 - val_loss: 0.5336 - val_accuracy: 0.8372
# Epoch 10/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5379 - accuracy: 0.8421 - val_loss: 0.4110 - val_accuracy: 0.8823
# Epoch 11/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.5125 - accuracy: 0.8507 - val_loss: 0.4158 - val_accuracy: 0.8821
# Epoch 12/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4950 - accuracy: 0.8585 - val_loss: 0.4034 - val_accuracy: 0.8852
# Epoch 13/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4758 - accuracy: 0.8629 - val_loss: 0.3902 - val_accuracy: 0.8865
# Epoch 14/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4663 - accuracy: 0.8675 - val_loss: 0.3797 - val_accuracy: 0.8887
# Epoch 15/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4540 - accuracy: 0.8705 - val_loss: 0.4090 - val_accuracy: 0.8792
# Epoch 16/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4348 - accuracy: 0.8743 - val_loss: 0.4002 - val_accuracy: 0.8831
# Epoch 17/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4212 - accuracy: 0.8823 - val_loss: 0.3746 - val_accuracy: 0.8896
# Epoch 18/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4224 - accuracy: 0.8807 - val_loss: 0.3494 - val_accuracy: 0.8992
# Epoch 19/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.4058 - accuracy: 0.8853 - val_loss: 0.3588 - val_accuracy: 0.8963
# Epoch 20/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3908 - accuracy: 0.8863 - val_loss: 0.3518 - val_accuracy: 0.8966
# Epoch 21/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3782 - accuracy: 0.8907 - val_loss: 0.3529 - val_accuracy: 0.8985
# Epoch 22/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3722 - accuracy: 0.8947 - val_loss: 0.3388 - val_accuracy: 0.9026
# Epoch 23/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3606 - accuracy: 0.8984 - val_loss: 0.3277 - val_accuracy: 0.9050
# Epoch 24/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3692 - accuracy: 0.8959 - val_loss: 0.3337 - val_accuracy: 0.9046
# Epoch 25/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3522 - accuracy: 0.9012 - val_loss: 0.3137 - val_accuracy: 0.9103
# Epoch 26/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3475 - accuracy: 0.9030 - val_loss: 0.3278 - val_accuracy: 0.9066
# Epoch 27/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3416 - accuracy: 0.9069 - val_loss: 0.3241 - val_accuracy: 0.9053
# Epoch 28/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3358 - accuracy: 0.9084 - val_loss: 0.3016 - val_accuracy: 0.9170
# Epoch 29/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3271 - accuracy: 0.9092 - val_loss: 0.3040 - val_accuracy: 0.9125
# Epoch 30/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3274 - accuracy: 0.9062 - val_loss: 0.3051 - val_accuracy: 0.9123
# Epoch 31/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3182 - accuracy: 0.9105 - val_loss: 0.3128 - val_accuracy: 0.9099
# Epoch 32/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3070 - accuracy: 0.9125 - val_loss: 0.3019 - val_accuracy: 0.9142
# Epoch 33/60
# 802/802 [==============================] - 7s 9ms/step - loss: 0.3074 - accuracy: 0.9132 - val_loss: 0.3022 - val_accuracy: 0.9138

# %%
plot_metrics(history_cnn.history)

# %% [markdown]
# ## 4. Get model predictions
# * Load the best weights for the MLP and CNN models that you saved during the training run.
# * Randomly select 5 images and corresponding labels from the test set and display the images with their labels.
# * Alongside the image and label, show each model’s predictive distribution as a bar chart, and the final model prediction given by the label with maximum probability.

# %%
def plot_sample_images_with_distribution(x, y, model=None, cmap=None):
  fig, axs = plt.subplots(2,10, figsize=(20, 5))
  img_idx = list(range(x.shape[0]))
  np.random.shuffle(img_idx)

  ax0 = axs[0]
  ax1 = axs[1]
  for i, idx in enumerate(img_idx[:10]):
    ax0[i].axis('off')
    ax0[i].imshow(np.squeeze(x[idx]), cmap=cmap)
    if not model:
      ax0[i].set_title(str(np.squeeze(y[idx])))
    else:
      xp = x[idx]
      xp = xp[np.newaxis, ...]
      pred = model.predict(xp)
      out = np.argmax(pred) + 1
      ax0[i].set_title(str(np.squeeze(y[idx])) +'=='+ str(out))

      pred = np.squeeze(pred)
      ax1[i].bar(list(range(len(pred))), pred)

# %%
tmp = gray_train_X[0]
pred = model.predict(tmp[np.newaxis, ...])
pred = np.squeeze(pred)
plt.bar(list(range(len(pred))), pred)
# Out:
# <BarContainer object of 10 artists>

# %%
model = get_new_model(gray_train_X.shape[1:])
model.load_weights(tf.train.latest_checkpoint('checkpoints'));
plot_sample_images_with_distribution(gray_train_X, train_y, model=model, cmap='gray')

# %%
cnn_model = get_new_cnn_model(gray_train_X.shape[1:])
cnn_model.load_weights(tf.train.latest_checkpoint('checkpoints_cnn'));
plot_sample_images_with_distribution(gray_train_X, train_y, model=cnn_model, cmap='gray')
